# %%
import pandas as pd

# %%
df = pd.read_csv('celebrity.csv')

# %%
df
# Out:
#                 Name                                  career_high_point  \
# 0        Virat Kohli                  ICC cricketer of the year in 2018
# 1       Akshay Kumar  Was the only Indian to be on the Forbes US lis...
# 2        Salman Khan  Consistently delivers Rs 100 crore-films—14 so...
# 3   Amitabh Bachchan  Was conferred the Padma Vibhushan in 2015, and...
# 4           MS Dhoni            Leading India to the 2011 World Cup win
# ..               ...                                                ...
# 95      Ranveer Brar  Became the country's youngest executive chef a...
# 96      Vikas Khanna  His restaurant Junoon in New York won a Michel...
# 97     Rohan Bopanna  Won the 2017 French Open mixed doubles with Ga...
# 98     Vicky Ratnani  Was appointed the personal chef to Nelson Mand...
# 99     Saransh Goila  Appeared as a guest judge on Masterchef Austra...
#
#     earnings_2019_In_Rs_crore  \
# 0                      252.72
# 1                      293.25
# ...
